# %%
import numpy as np
import os
import os.path
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import cv2

# %%
img_dir = '/home/srini/HDD/deep_learning_assignments/project/specialized-superpoint/'
file = os.path.join(img_dir,'1542382557.504291_preprocessed/qc_left_br_017_1500997703.54.png')
img = cv2.imread(file)
plt.imshow(img)

# %%
file = os.path.join(img_dir,'1542382611.6805966_preprocessed/qc_left_br_017_1500997703.54.png')
img = cv2.imread(file)
plt.imshow(img)

# %%
file = os.path.join(img_dir,'qc_left_br_001_1500997698.73.png')
img = cv2.imread(file,0)
plt.imshow(img)
