# %%
import numpy as np
import os
import os.path
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import cv2

# %%
img_dir = '/home/srini/HDD/deep_learning_assignments/project/specialized-superpoint/'
file = os.path.join(img_dir,'1542382557.504291_preprocessed/qc_right_bl_090_1500997722.71.png')
img = cv2.imread(file)
plt.imshow(img)

# %%
file = os.path.join(img_dir,'1542382611.6805966_preprocessed/qc_right_bl_090_1500997722.71.png')
img = cv2.imread(file,0)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-2e53e9bb7fcb> in <module>()
#       1 file = os.path.join(img_dir,'1542382611.6805966_preprocessed/qc_right_bl_090_1500997722.71.png')
#       2 img = cv2.imread(file,0)
# ----> 3 plt.imshow(img)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3208                         filternorm=filternorm, filterrad=filterrad,
#    3209                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3210                         **kwargs)
#    3211     finally:
#    3212         ax._hold = washold
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
file = os.path.join(img_dir,'qc_left_br_001_1500997698.73.png')
img = cv2.imread(file,0)
plt.imshow(img)
