# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
from shapes_loader import *

dataset_path = './datasets/synthetic_shapes_v6/'

train_loader = DataLoader(ShapesLoader(mode='validation',dataset_path='./datasets/synthetic_shapes_v6/'),batch_size=64,shuffle=True)
# Out:
# Looking into dataset dir for validation data
# Loading images and points from draw_lines
# Loading images and points from draw_polygon
# Loading images and points from draw_checkerboard
# Loading images and points from gaussian_noise
# Loading images and points from draw_ellipses
# Loading images and points from draw_stripes
# Loading images and points from draw_star
# Loading images and points from draw_cube
# Loading images and points from draw_multiple_polygons
# Finished loading the synthetic shapes dataset. Took:0.584 s

# %%
for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
    pdb.set_trace()
    fig=plt.figure(figsize=(8, 8))
    columns = 8
    rows = 8
    
    for i in range(1, columns*rows):
        fig.add_subplot(rows, columns, i)
        plt.imshow(imgs[i])
        
    plt.show()
# Out:
# > <ipython-input-3-d50a0bf19111>(4)<module>()
# -> fig=plt.figure(figsize=(8, 8))
# (Pdb) c
# > <ipython-input-3-d50a0bf19111>(3)<module>()
# -> pdb.set_trace()
# (Pdb) c
# > <ipython-input-3-d50a0bf19111>(4)<module>()
# -> fig=plt.figure(figsize=(8, 8))
# (Pdb) didx
# ('draw_stripes104', 'draw_stripes34', 'draw_lines81', 'draw_checkerboard47', 'draw_checkerboard152', 'draw_lines148', 'draw_lines60', 'draw_polygon84', 'gaussian_noise67', 'draw_multiple_polygons100', 'draw_polygon10', 'gaussian_noise6', 'draw_checkerboard154', 'draw_polygon61', 'draw_cube123', 'draw_ellipses147', 'draw_star80', 'draw_multiple_polygons123', 'draw_multiple_polygons94', 'draw_polygon46', 'draw_polygon92', 'draw_checkerboard68', 'draw_stripes50', 'draw_cube150', 'draw_multiple_polygons64', 'gaussian_noise95', 'draw_lines30', 'draw_ellipses194', 'gaussian_noise98', 'draw_star192', 'draw_lines23', 'draw_cube128', 'gaussian_noise169', 'draw_stripes14', 'draw_ellipses198', 'gaussian_noise28', 'draw_star61', 'gaussian_noise129', 'draw_multiple_polygons6', 'draw_star118', 'draw_stripes87', 'draw_star57', 'draw_stripes125', 'draw_polygon4', 'draw_cube17', 'draw_star150', 'draw_checkerboard12', 'draw_stripes67', 'gaussian_noise8', 'draw_stripes68', 'gaussian_noise77', 'draw_ellipses88', 'draw_star137', 'draw_lines73', 'draw_lines171', 'draw_multiple_polygons125', 'draw_lines137', 'draw_lines77', 'gaussian_noise112', 'draw_star106', 'draw_star17', 'draw_stripes8', 'gaussian_noise149', 'draw_multiple_polygons175')
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-3-d50a0bf19111> in <module>()
#       2 for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
#       3     pdb.set_trace()
# ----> 4     fig=plt.figure(figsize=(8, 8))
#       5     columns = 8
#       6     rows = 8
#
# <ipython-input-3-d50a0bf19111> in <module>()
#       2 for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
#       3     pdb.set_trace()
# ----> 4     fig=plt.figure(figsize=(8, 8))
#       5     columns = 8
#       6     rows = 8
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:
