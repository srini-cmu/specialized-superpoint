# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
from shapes_loader import *

dataset_path = './datasets/synthetic_shapes_v6/'

train_loader = DataLoader(ShapesLoader(mode='validation',dataset_path='./datasets/synthetic_shapes_v6/'),batch_size=64,shuffle=True)

# %%
for batch_idx, (imgs,pts) in enumerate(train_loader):
    #pdb.set_trace()
    fig=plt.figure(figsize=(8, 8))
    columns = 8
    rows = 8
    
    for i in range(1, columns*rows):
        fig.add_subplot(rows, columns, i)
        plt.imshow(imgs[i])
        
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-7bdd6ef14a76> in <module>()
#      10         plt.imshow(imgs[i])
#      11
# ---> 12     plt.show()
#      13
#      14
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
files = os.listdir(dataset_path)

# %%
print(files)
# Out:
# ['draw_lines', 'draw_polygon', 'draw_checkerboard', 'gaussian_noise', 'draw_ellipses', 'draw_stripes', 'draw_star', 'draw_cube', 'draw_multiple_polygons']

# %%
dset_types = files
dset_idx = 2
img_idx = 1000
img = dataset_path+'/'+dset_types[dset_idx]+'/images/training/'+str(idx)+'.png'
pt = dataset_path+'/'+dset_types[dset_idx]+'/points/training/'+str(idx)+'.npy'

im = np.array(Image.open(img))
p = np.load(pt)
plt.imshow(im)
plt.show()

print(p)
# Out:
# [[  2.5     5.75 ]
#  [ 23.25    2.875]
#  [ 19.625  21.5  ]
#  [ 15.625  41.75 ]
#  [ 11.25   64.125]
#  [  6.5    88.75 ]
#  [ 43.125   0.   ]
#  [ 40.5    18.25 ]
#  [ 37.5    38.   ]
#  [ 34.25   59.625]
#  [ 30.75   83.5  ]
#  [ 60.625  15.   ]
#  [ 58.625  34.375]
#  [ 56.5    55.375]
#  [ 54.     78.5  ]
#  [ 80.     12.   ]
#  [ 78.875  30.75 ]
#  [ 77.75   51.25 ]
#  [ 76.375  73.75 ]
#  [ 98.75    9.   ]
#  [ 98.5    27.375]
#  [ 98.25   47.375]
#  [ 97.875  69.25 ]
#  [116.875   6.25 ]
#  [117.375  24.125]
#  [117.875  43.5  ]
#  [118.5    64.75 ]]
