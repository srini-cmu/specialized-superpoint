# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
from shapes_loader import *

dataset_path = './datasets/synthetic_shapes_v6/'

train_loader = DataLoader(ShapesLoader(mode='validation',dataset_path='./datasets/synthetic_shapes_v6/'),batch_size=64,shuffle=True,collate_fn=collate_fn)
# Out:
# Looking into dataset dir for validation data
# Loading images and points from draw_lines
# Loading images and points from draw_polygon
# Loading images and points from draw_checkerboard
# Loading images and points from gaussian_noise
# Loading images and points from draw_ellipses
# Loading images and points from draw_stripes
# Loading images and points from draw_star
# Loading images and points from draw_cube
# Loading images and points from draw_multiple_polygons
# Finished loading the synthetic shapes dataset. Took:0.588 s

# %%
for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
    pdb.set_trace()
    fig=plt.figure(figsize=(8, 8))
    columns = 8
    rows = 8
    
    for i in range(1, columns*rows):
        fig.add_subplot(rows, columns, i)
        plt.imshow(imgs[i])
        
    plt.show()
# Out:
# > <ipython-input-4-d50a0bf19111>(4)<module>()
# -> fig=plt.figure(figsize=(8, 8))
# (Pdb) c
# > <ipython-input-4-d50a0bf19111>(3)<module>()
# -> pdb.set_trace()
# (Pdb) didx
# ('draw_multiple_polygons137', 'gaussian_noise167', 'draw_star37', 'draw_checkerboard113', 'draw_ellipses58', 'draw_ellipses63', 'draw_star129', 'draw_multiple_polygons104', 'gaussian_noise110', 'draw_cube23', 'draw_multiple_polygons82', 'draw_checkerboard177', 'draw_star164', 'draw_ellipses194', 'gaussian_noise82', 'draw_cube18', 'draw_checkerboard155', 'draw_checkerboard26', 'draw_cube19', 'draw_ellipses20', 'draw_cube13', 'gaussian_noise1', 'gaussian_noise15', 'draw_multiple_polygons74', 'gaussian_noise144', 'draw_multiple_polygons111', 'draw_ellipses133', 'draw_cube45', 'draw_lines32', 'draw_polygon75', 'draw_polygon5', 'draw_ellipses119', 'draw_star25', 'draw_checkerboard170', 'draw_checkerboard12', 'draw_polygon53', 'draw_multiple_polygons93', 'draw_polygon184', 'gaussian_noise29', 'draw_ellipses83', 'draw_checkerboard179', 'draw_star118', 'draw_lines23', 'draw_star169', 'draw_ellipses137', 'draw_cube44', 'draw_stripes136', 'draw_polygon122', 'draw_cube66', 'draw_lines181', 'draw_stripes35', 'draw_stripes168', 'draw_polygon186', 'draw_star197', 'draw_lines192', 'draw_lines114', 'draw_lines109', 'draw_lines188', 'draw_polygon93', 'draw_multiple_polygons144', 'gaussian_noise61', 'draw_lines143', 'draw_multiple_polygons184', 'draw_stripes165')
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-4-d50a0bf19111> in <module>()
#       1
#       2 for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
# ----> 3     pdb.set_trace()
#       4     fig=plt.figure(figsize=(8, 8))
#       5     columns = 8
#
# <ipython-input-4-d50a0bf19111> in <module>()
#       1
#       2 for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
# ----> 3     pdb.set_trace()
#       4     fig=plt.figure(figsize=(8, 8))
#       5     columns = 8
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:
