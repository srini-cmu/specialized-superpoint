# %%
import numpy as np
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %%
from shapes_loader import *

dataset_path = './datasets/synthetic_shapes_v6/'

train_loader = DataLoader(ShapesLoader(mode='validation',dataset_path='./datasets/synthetic_shapes_v6/'),batch_size=64,shuffle=True)
# Out:
# Looking into dataset dir for validation data
# Loading images and points from draw_lines
# Loading images and points from draw_polygon
# Loading images and points from draw_checkerboard
# Loading images and points from gaussian_noise
# Loading images and points from draw_ellipses
# Loading images and points from draw_stripes
# Loading images and points from draw_star
# Loading images and points from draw_cube
# Loading images and points from draw_multiple_polygons
# Finished loading the synthetic shapes dataset. Took:0.568 s

# %%
for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
    pdb.set_trace()
    fig=plt.figure(figsize=(8, 8))
    columns = 8
    rows = 8
    
    for i in range(1, columns*rows):
        fig.add_subplot(rows, columns, i)
        plt.imshow(imgs[i])
        
    plt.show()
# Out:
# > <ipython-input-3-d50a0bf19111>(4)<module>()
# -> fig=plt.figure(figsize=(8, 8))
# (Pdb) c
# > <ipython-input-3-d50a0bf19111>(3)<module>()
# -> pdb.set_trace()
# (Pdb) didx
# ('draw_multiple_polygons184', 'draw_multiple_polygons43', 'draw_multiple_polygons135', 'draw_multiple_polygons181', 'draw_multiple_polygons132', 'draw_multiple_polygons48', 'draw_multiple_polygons61', 'draw_multiple_polygons50', 'draw_multiple_polygons114', 'draw_multiple_polygons56', 'draw_multiple_polygons139', 'draw_multiple_polygons115', 'draw_multiple_polygons93', 'draw_multiple_polygons111', 'draw_multiple_polygons150', 'draw_multiple_polygons158', 'draw_multiple_polygons106', 'draw_multiple_polygons100', 'draw_multiple_polygons31', 'draw_multiple_polygons189', 'draw_multiple_polygons27', 'draw_multiple_polygons68', 'draw_multiple_polygons199', 'draw_multiple_polygons113', 'draw_multiple_polygons87', 'draw_multiple_polygons73', 'draw_multiple_polygons186', 'draw_multiple_polygons182', 'draw_multiple_polygons3', 'draw_multiple_polygons28', 'draw_multiple_polygons90', 'draw_multiple_polygons178', 'draw_multiple_polygons125', 'draw_multiple_polygons32', 'draw_multiple_polygons55', 'draw_multiple_polygons59', 'draw_multiple_polygons54', 'draw_multiple_polygons187', 'draw_multiple_polygons145', 'draw_multiple_polygons95', 'draw_multiple_polygons0', 'draw_multiple_polygons176', 'draw_multiple_polygons26', 'draw_multiple_polygons128', 'draw_multiple_polygons190', 'draw_multiple_polygons25', 'draw_multiple_polygons180', 'draw_multiple_polygons62', 'draw_multiple_polygons78', 'draw_multiple_polygons40', 'draw_multiple_polygons15', 'draw_multiple_polygons4', 'draw_multiple_polygons89', 'draw_multiple_polygons63', 'draw_multiple_polygons130', 'draw_multiple_polygons67', 'draw_multiple_polygons5', 'draw_multiple_polygons37', 'draw_multiple_polygons46', 'draw_multiple_polygons193', 'draw_multiple_polygons23', 'draw_multiple_polygons102', 'draw_multiple_polygons6', 'draw_multiple_polygons11')
# (Pdb) c
# > <ipython-input-3-d50a0bf19111>(4)<module>()
# -> fig=plt.figure(figsize=(8, 8))
# (Pdb) didx
# ('draw_multiple_polygons36', 'draw_multiple_polygons196', 'draw_multiple_polygons71', 'draw_multiple_polygons24', 'draw_multiple_polygons107', 'draw_multiple_polygons42', 'draw_multiple_polygons94', 'draw_multiple_polygons66', 'draw_multiple_polygons162', 'draw_multiple_polygons41', 'draw_multiple_polygons35', 'draw_multiple_polygons65', 'draw_multiple_polygons119', 'draw_multiple_polygons75', 'draw_multiple_polygons81', 'draw_multiple_polygons198', 'draw_multiple_polygons45', 'draw_multiple_polygons171', 'draw_multiple_polygons170', 'draw_multiple_polygons144', 'draw_multiple_polygons118', 'draw_multiple_polygons169', 'draw_multiple_polygons64', 'draw_multiple_polygons165', 'draw_multiple_polygons173', 'draw_multiple_polygons160', 'draw_multiple_polygons21', 'draw_multiple_polygons177', 'draw_multiple_polygons122', 'draw_multiple_polygons188', 'draw_multiple_polygons117', 'draw_multiple_polygons146', 'draw_multiple_polygons121', 'draw_multiple_polygons192', 'draw_multiple_polygons112', 'draw_multiple_polygons33', 'draw_multiple_polygons58', 'draw_multiple_polygons83', 'draw_multiple_polygons60', 'draw_multiple_polygons141', 'draw_multiple_polygons77', 'draw_multiple_polygons99', 'draw_multiple_polygons174', 'draw_multiple_polygons127', 'draw_multiple_polygons197', 'draw_multiple_polygons154', 'draw_multiple_polygons80', 'draw_multiple_polygons1', 'draw_multiple_polygons185', 'draw_multiple_polygons109', 'draw_multiple_polygons2', 'draw_multiple_polygons84', 'draw_multiple_polygons172', 'draw_multiple_polygons8', 'draw_multiple_polygons52', 'draw_multiple_polygons76', 'draw_multiple_polygons110', 'draw_multiple_polygons129', 'draw_multiple_polygons29', 'draw_multiple_polygons140', 'draw_multiple_polygons131', 'draw_multiple_polygons151', 'draw_multiple_polygons82', 'draw_multiple_polygons34')
# (Pdb) q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-3-d50a0bf19111> in <module>()
#       2 for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
#       3     pdb.set_trace()
# ----> 4     fig=plt.figure(figsize=(8, 8))
#       5     columns = 8
#       6     rows = 8
#
# <ipython-input-3-d50a0bf19111> in <module>()
#       2 for batch_idx, (imgs,pts,didx) in enumerate(train_loader):
#       3     pdb.set_trace()
# ----> 4     fig=plt.figure(figsize=(8, 8))
#       5     columns = 8
#       6     rows = 8
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/bdb.py in trace_dispatch(self, frame, event, arg)
#      49             return # None
#      50         if event == 'line':
# ---> 51             return self.dispatch_line(frame)
#      52         if event == 'call':
#      53             return self.dispatch_call(frame, arg)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/bdb.py in dispatch_line(self, frame)
#      68         if self.stop_here(frame) or self.break_here(frame):
#      69             self.user_line(frame)
# ---> 70             if self.quitting: raise BdbQuit
#      71         return self.trace_dispatch
#      72
#
# BdbQuit:
